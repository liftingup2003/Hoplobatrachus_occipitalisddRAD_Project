# %%
import ipyrad.analysis as ipa
import toyplot
import pandas as pd

# %%
data = "/home/iovercast/hoplo_assembly/Hoplo-SE_outfiles/Hoplo-SE.snps.hdf5"

# %%
metadata = pd.read_csv("Hoplo_metadata_FIXED.csv", index_col="Seq ID")

#metadata= metadata.drop (['HOOC0024', 'HOOC0039', 'HOOC0047'])
metadata.index = [x+".trimmed" for x in metadata.index]
metadata= metadata.drop (['HOOC0005.trimmed', 'HOOC0006.trimmed', 'HOOC0014.trimmed', 'HOOC0015.trimmed', 'HOOC0021.trimmed', 
                          'HOOC0022.trimmed', 'HOOC0023.trimmed', 'HOOC0029.trimmed', 'HOOC0030.trimmed', 'HOOC0038.trimmed', 
                          'HOOC0040.trimmed', 'HOOC0046.trimmed', 'HOOC0053.trimmed', 'HOOC0054.trimmed', 'HOOC0056.trimmed', 
                          'HOOC0057.trimmed', 'HOOC0062.trimmed', 'HOOC0084.trimmed', 'HOOC0085.trimmed', 'HOOC0086.trimmed', 
                          'HOOC0087.trimmed', 'HOOC0088.trimmed', 'HOOC0089.trimmed', 'HOOC0090.trimmed', 'HOOC0091.trimmed', 
                          'HOOC0093.trimmed'])

imap = metadata.groupby("Vegetation zone").groups
zones = ["Mangrove Forest", "Rainforest", "Derived savanna", "Giunea savanna"]
imap = {x:imap[x].tolist() for x in zones}
# require that 50% of samples have data in each group
minmap = {i: 0.5 for i in imap}
imap
# Out:
# {'Mangrove Forest': ['HOOC0001.trimmed',
#   'HOOC0002.trimmed',
#   'HOOC0003.trimmed',
#   'HOOC0009.trimmed',
#   'HOOC0010.trimmed',
#   'HOOC0011.trimmed',
#   'HOOC0017.trimmed',
#   'HOOC0018.trimmed',
#   'HOOC0019.trimmed',
#   'HOOC0025.trimmed',
#   'HOOC0026.trimmed',
#   'HOOC0027.trimmed',
#   'HOOC0033.trimmed',
#   'HOOC0034.trimmed',
#   'HOOC0035.trimmed',
#   'HOOC0041.trimmed',
#   'HOOC0042.trimmed',
#   'HOOC0049.trimmed',
#   'HOOC0050.trimmed',
#   'HOOC0058.trimmed',
#   'HOOC0065.trimmed',
#   'HOOC0066.trimmed',
#   'HOOC0073.trimmed',
#   'HOOC0074.trimmed',
#   'HOOC0081.trimmed',
#   'HOOC0082.trimmed'],
#  'Rainforest': ['HOOC0004.trimmed',
#   'HOOC0012.trimmed',
#   'HOOC0013.trimmed',
#   'HOOC0020.trimmed',
#   'HOOC0028.trimmed',
#   'HOOC0036.trimmed',
#   'HOOC0037.trimmed',
#   'HOOC0043.trimmed',
#   'HOOC0044.trimmed',
#   'HOOC0045.trimmed',
#   'HOOC0051.trimmed',
#   'HOOC0052.trimmed',
#   'HOOC0059.trimmed',
#   'HOOC0060.trimmed',
#   'HOOC0061.trimmed',
#   'HOOC0067.trimmed',
#   'HOOC0068.trimmed',
#   'HOOC0069.trimmed',
#   'HOOC0075.trimmed',
#   'HOOC0076.trimmed',
#   'HOOC0077.trimmed',
#   'HOOC0083.trimmed',
#   'HOOC0092.trimmed'],
#  'Derived savanna': ['HOOC0007.trimmed',
#   'HOOC0008.trimmed',
#   'HOOC0016.trimmed',
#   'HOOC0031.trimmed',
#   'HOOC0055.trimmed',
#   'HOOC0063.trimmed',
#   'HOOC0070.trimmed',
#   'HOOC0071.trimmed',
#   'HOOC0078.trimmed',
#   'HOOC0079.trimmed',
#   'HOOC0094.trimmed',
#   'HOOC0095.trimmed'],
#  'Giunea savanna': ['HOOC0032.trimmed',
#   'HOOC0048.trimmed',
#   'HOOC0064.trimmed',
#   'HOOC0072.trimmed',
#   'HOOC0080.trimmed',
#   'HOOC0096.trimmed']}

# %%
# init analysis object with input data and (optional) parameter options
struct = ipa.structure(
    name="denovohoplostructure",
    data=data,
    imap=imap,
    minmap=minmap,
    mincov=0.9,
)
# Out:
# 12 previous results loaded for run [denovohoplostructure]
# Samples: 67
# Sites before filtering: 160046
# Filtered (indels): 31387
# Filtered (bi-allel): 22981
# Filtered (mincov): 135134
# Filtered (minmap): 93569
# Filtered (subsample invariant): 14598
# Filtered (minor allele frequency): 0
# Filtered (combined): 137500
# Sites after filtering: 21079
# Sites containing missing values: 19368 (91.88%)
# Missing values in SNP matrix: 66431 (4.70%)
# SNPs (total): 21079
# SNPs (unlinked): 7453

# %%
struct.mainparams.burnin = 5000
struct.mainparams.numreps = 10000

# %%
struct.ipcluster['cores']=12
struct.ipcluster
# Out:
# {'cluster_id': '',
#  'profile': 'default',
#  'engines': 'Local',
#  'quiet': 0,
#  'timeout': 60,
#  'cores': 12,
#  'threads': 2,
#  'pids': {}}

# %%
struct.run(nreps=3, kpop=[2, 3, 4, 5], auto=True, force=True)
# Out:
# [####################] 100% 0:12:11 | running 12 structure jobs

# %%
etable = struct.get_evanno_table([2, 3, 4, 5])

etable
# Out:
# /home/ocoker/ipyrad/ipyrad/analysis/structure.py:1036: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-869105.8' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tab.loc[kpop, "lnPK"] = tab.loc[kpop, "estLnProbMean"] \
# /home/ocoker/ipyrad/ipyrad/analysis/structure.py:1040: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1745968.9333333336' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tab.loc[kpop, "lnPPK"] = abs(tab.loc[kpop+1, "lnPK"]
# /home/ocoker/ipyrad/ipyrad/analysis/structure.py:1042: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.47219600701867' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tab.loc[kpop, "deltaK"] = (abs(
#    Nreps        lnPK      lnPPK    deltaK  estLnProbMean  estLnProbStdev
# 2      3       0.000  0.000e+00     0.000     -2.290e+05       1.201e+03
# 3      3 -869105.800  1.746e+06     1.472     -1.098e+06       1.186e+06
# 4      3  876863.133  8.749e+05  1055.260     -2.212e+05       8.291e+02
# 5      3    1924.200  0.000e+00     0.000     -2.193e+05       3.199e+03

# %%
import toyplot.png
toyplot.png.render(canvas,'ddRADstructuretable.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import toyplot.png
# ----> 2 toyplot.png.render(canvas,'ddRADstructuretable.png')
#
# NameError: name 'canvas' is not defined

# %%
# get canvas object and set size
canvas = toyplot.Canvas(width=400, height=300)

# plot the mean log probability of the models in red
axes = canvas.cartesian(ylabel="estLnProbMean")
axes.plot(etable.estLnProbMean * -1, color="darkred", marker="o")
axes.y.spine.style = {"stroke": "darkred"}

# plot delta K with its own scale bar of left side and in blue
axes = axes.share("x", ylabel="deltaK", ymax=etable.deltaK.max() + etable.deltaK.max() * .25)
axes.plot(etable.deltaK, color="steelblue", marker="o");
axes.y.spine.style = {"stroke": "steelblue"}

# set x labels
axes.x.ticks.locator = toyplot.locator.Explicit(range(len(etable.index)), etable.index)
axes.x.label.text = "K (N ancestral populations)"
# Out:
# <div class="toyplot" id="tc2068599bb9c467994afcdc36e9c00b3" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tf24563c8876d47c095f1dddeef5ad686"><g class="toyplot-coordinates-Cartesian" id="t5ab15f0133224ef4963a42707e80e1e2"><clipPath id="t65b870d92e134720ac07678b44c57c5a"><rect x="40.0" y="40.0" width="320.0" height="220.0"></rect></clipPath><g clip-path="url(#t65b870d92e134720ac07678b44c57c5a)"><g class="toyplot-mark-Plot" style="fill:none" id="tf264fc6d4cbe41d98f6dc29725db4023"><g class="toyplot-Series"><path d="M 50.0 247.79661518410597 L 150.0 50.0 L 249.99999999999997 249.5620783488762 L 350.0 250.0" style="stroke:rgb(54.5%,0%,0%);stroke-opacity:1.0;stroke-width:2.0"></path><g style="fill:rgb(54.5%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(54.5%,0%,0%);stroke-opacity:1.0" class="toyplot-Datum" transform="translate(50.0, 247.79661518410597)"><circle r="2.0"></circle></g><g style="fill:rgb(54.5%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(54.5%,0%,0%);stroke-opacity:1.0" class="toyplot-Datum" transform="translate(150.0, 50.0)"><circle r="2.0"></circle></g><g style="fill:rgb(54.5%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(54.5%,0%,0%);stroke-opacity:1.0" class="toyplot-Datum" transform="translate(249.99999999999997, 249.5620783488762)"><circle r="2.0"></circle></g><g style="fill:rgb(54.5%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(54.5%,0%,0%);stroke-opacity:1.0" class="toyplot-Datum" transform="translate(350.0, 250.0)"><circle r="2.0"></circle></g></g></g></g><g class="toyplot-coordinates-Axis" id="tb2fc4d2a1c3b4af2a86addaf7fd49ff7" transform="translate(50.0,250.0)translate(0,10.0)"><line x1="0" y1="0" x2="300.0" y2="0" style=""></line><g><g transform="translate(0.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">2</text></g><g transform="translate(100.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">3</text></g><g transform="translate(200.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">4</text></g><g transform="translate(300.0,6)"><text x="-2.78" y="8.555" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:10.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre">5</text></g></g><g transform="translate(150.0,22)"><text x="-78.012" y="10.265999999999998" style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:12.0px;font-weight:bold;stroke:none;vertical-align:baseline;white-space:pre">K (N ancestral populations)</text></g><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line x1="0" x2="0" y1="-3.0" y2="4.5" style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0"></line><text x="0" y="-6" style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle"></text></g></g><g class="toyplot-coordinates-Axis" id="t86c2ad145bc34e6180599fab94a3fa63" transform="translate(50.0,250.0)rotate(-90.0)translate(0,-10.0)"><line x1="0" y1="0" x2="200.0" y2="0" style="stroke:rgb(54.5%,0%,0%);stroke-opa ...

# %%
k = 4
table = struct.get_clumpp_table(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 k = 4
# ----> 2 table = struct.get_clumpp_table(k)
#
# NameError: name 'struct' is not defined

# %%
# sort list by columns
table.sort_values(by=list(range(k)), inplace=True)

# or, sort by a list of names (here taken from imap)
import itertools
onames = list(itertools.chain(*imap.values()))
table = table.loc[onames]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # sort list by columns
# ----> 2 table.sort_values(by=list(range(k)), inplace=True)
#       4 # or, sort by a list of names (here taken from imap)
#       5 import itertools
#
# NameError: name 'table' is not defined

# %%
# build barplot
canvas = toyplot.Canvas(width=1000, height=250)
axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
axes.bars(table)

# add labels to x-axis
ticklabels = [i for i in table.index.tolist()]
axes.x.ticks.locator = toyplot.locator.Explicit(labels=ticklabels)
axes.x.ticks.labels.angle = -60
axes.x.ticks.show = True
axes.x.ticks.labels.offset = 10
axes.x.ticks.labels.style = {"font-size": "12px"}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # build barplot
# ----> 2 canvas = toyplot.Canvas(width=1000, height=250)
#       3 axes = canvas.cartesian(bounds=("10%", "90%", "10%", "45%"))
#       4 axes.bars(table)
#
# NameError: name 'toyplot' is not defined

# %%
import toyplot.png
toyplot.png.render(canvas,'ddRADstructure1.png')
