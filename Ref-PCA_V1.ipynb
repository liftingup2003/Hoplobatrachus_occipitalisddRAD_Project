# %%
import ipyrad.analysis as ipa

# %%
data = "hoploreference_outfiles/hoploreference.snps.hdf5"
## Create the pca object
pca = ipa.pca(data)
## Run the analysis
pca.run()
## Bam!
pca.draw()
# Out:
# Samples: 94
# Sites before filtering: 280267
# Filtered (indels): 0
# Filtered (bi-allel): 5412
# Filtered (mincov): 33436
# Filtered (minmap): 0
# Filtered (subsample invariant): 0
# Filtered (minor allele frequency): 0
# Filtered (combined): 38415
# Sites after filtering: 242095
# Sites containing missing values: 242064 (99.99%)
# Missing values in SNP matrix: 9615592 (42.25%)
# SNPs (total): 242095
# SNPs (unlinked): 51011
# Imputation (null; sets to 0): 100.0%, 0.0%, 0.0%
# Subsampling SNPs: 51011/242095
# (<toyplot.canvas.Canvas at 0x7f12f92a3200>,
#  <toyplot.coordinates.Cartesian at 0x7f12fabae7b0>)
# <div class="toyplot" id="tebbe04c9214042f39525f768beb40a8e" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tb33f87ed54024643b8473381eeba3cf4"><g class="toyplot-coordinates-Cartesian" id="t09907474a56e4aceb7851d5353243e78"><clipPath id="tcabd420865d84893aecfda6237647004"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#tcabd420865d84893aecfda6237647004)"><g class="toyplot-mark-Point" id="t28fc7aa2908d4b689036aead8cdaee30"><g class="toyplot-Series"><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(54.71360210944714), np.float64(242.57931795011208))"><title>reference</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(65.5973757285288), np.float64(152.0458611197822))"><title>HOOC0001</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(68.55424070336474), np.float64(154.35381480704174))"><title>HOOC0002</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(63.7683033970161), np.float64(154.5853495413108))"><title>HOOC0003</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(66.98760334748653), np.float64(151.59003487903618))"><title>HOOC0004</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(210.84460262852176), np.float64(81.15410123540417))"><title>HOOC0005</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(200.16993221556527), np.float64(240.3156102657859))"><title>HOOC0006</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(68.18700145981893), np.float64(150.0061631297027))"><title>HOOC0007</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(68.89998728282926), np.float64(151.45091002398541))"><title>HOOC0008</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(np.float64(63.133357712306164), np.float64(153.3598970278538))"><title>HOOC0009</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke ...
